# %%
from datetime import datetime, timedelta
from json import loads as json_loads
from numpy import nan
from pandas import read_parquet
from tqdm.auto import tqdm

# %% [markdown]
# Testing Connection to AWS S3

# %%
# !aws s3 ls s3://
# Out:
# 2020-04-14 09:44:35 adc-ada1
# 2021-10-22 16:25:41 adc-aws-billing
# 2021-02-20 17:32:47 adc-cloudtrail-logs
# 2021-06-25 09:56:11 adc-cloudwatch-logs
# 2022-04-07 10:31:18 adc-de-dev
# 2021-06-04 09:47:20 adc-ds
# 2020-11-04 14:08:07 adc-ds-aspirasi-user
# 2020-11-04 14:09:42 adc-ds-athena-query-result
# 2021-10-04 11:45:34 adc-ds-cloudtrails
# 2020-10-20 12:17:11 adc-ds-custom-logs
# 2020-11-04 13:58:05 adc-ds-data
# 2021-03-23 23:05:51 adc-ds-detool
# 2020-11-04 14:11:21 adc-ds-dev
# 2021-06-15 09:44:15 adc-ds-factdata
# 2021-10-04 07:14:28 adc-ds-lms
# 2020-11-04 14:12:29 adc-ds-logging
# 2021-03-26 16:00:30 adc-ds-ml
# 2022-03-29 22:22:42 adc-ds-replicated-data
# 2020-05-19 08:27:10 adc-ds-s3-logs-ap-southeast-1
# 2021-12-18 21:57:35 adc-ds-scripts
# 2020-11-04 14:13:02 adc-ds-sftp
# 2020-03-03 12:26:31 adc-id-reporting
# 2020-11-12 00:37:47 adc-my-reporting
# 2021-06-01 21:02:43 adc-production-backups
# 2021-02-20 12:15:19 adc-production-firewal-log
# 2021-12-18 21:50:09 adc-replication-example
# 2021-06-07 21:37:06 adc-vpc-flow-logs
# 2020-10-20 18:16:00 aspirasi-assets
# 2021-07-16 21:33:38 aspirasi-cloudfront-logs
# 2021-02-09 10:23:03 aspirasi-co-assets
# 2020-04-11 05:32:02 aspirasi-dev
# 2020-10-27 16:21:57 aspirasi-dev-co
# 2021-05-28 17:35:03 aspirasi-dev-journeys
# 2020-07-31 12:26:20 aspirasi-epenjana
# 2021-03-03 10:50:29 aspirasi-financing-web-journeys
# 2019-12-12 14:40:46 aspirasi-insure-assets
# 2019-10-04 16:27:57 aspirasi-journey-api-dev-serverlessdeploymentbuck-kq9r615yrwh0
# 2021-06-24 19:01:18 aspirasi-paylater
# 2021-06-24 18:59:20 aspirasi-paylater-checkout
# 2022-02-18 14:34:04 aspirasi-paylater-uat
# 2021-07-11 01:05:49 aspirasi-stage
# 2020-04-22 13:02:40 aspirasi-static
# 2020-04-22 19:36:47 aspirasi-test
# 2021-02-09 10:22:18 aspirasi-uat-co-assets
# 2021-02-09 10:22:00 aspirasi-uat.co
# 2021-02-09 10:24:01 aspirasi.co
# 2021-06-22 15:05:14 aspirasi.co.backup
# 2019-09-25 01:13:42 aws-athena-query-results-500459076343-ap-southeast-1
# 2020-10-27 16:06:52 aws-glue-assets-500459076343-ap-southeast-1
# 2019-09-24 16:52:45 aws-glue-scripts-500459076343-ap-southeast-1
# 2019-09-24 16:52:47 aws-glue-temporary-500459076343-ap-southeast-1
# 2020-02-06 11:33:42 aws-id-reporting
# 2019-09-27 11:51:51 aws-logs-500459076343-ap-southeast-1
# 2019-09-25 10:49:07 aws-logs-500459076343-us-east-1
# 2020-03-06 13:10:38 aws-my-reporting
# 2021-05-28 11:06:33 bnpl-checkout-dev
# 2021-05-28 11:05:46 bnpl-checkout-stage
# 2019-09-23 18:24:13 boost-merchant-data
# 2021-03-13 09:38:28 cashnow-uat
# 2022-03-29 17:06:18 cdp-replication-logs
# 2019-05-24 15:35:30 cf-templates-1tzkjdcwzwdyf-ap-southeast-1
# 2020-09-28 10:25:21 config-bucket-500459076343
# 2020-03-18 12:03:40 custom-labels-console-us-east-1-f886878dd0
# 2020-04-22 13:42:10 default-query-results-500459076343-ap-southeast-1
# 2022-04-05 15:24:37 distributor-merchant-assets
# 2020-04-06 22:00:28 docker.aspirasium.com
# 2019-09-26 19:06:35 elasticbeanstalk-ap-southeast-1-500459076343
# 2019-12-31 18:03:51 funnel-ada-matta
# 2019-10-17 12:03:05 funnelmgr-leads
# 2019-12-15 11:42:09 ge-landing-production
# 2019-12-11 19:26:34 ge-landing-uat
# 2020-10-22 13:32:48 ghl-aspirasi-uat
# 2020-11-04 13:50:37 halim-bucket-dev
# 2020-01-09 23:18:41 join.aspirasi.co
# 2021-05-24 16:22:08 journey-external-lb-logs
# 2021-05-24 16:23:10 journey-uat-internal-lb
# 2021-01-15 10:57:02 kongsi-portal-assets
# 2020-12-21 09:45:39 kongsi-portal-dev
# 2020-12-24 16:52:15 kongsi-portal-prod
# 2020-02-19 15:56:06 lazada-aspirasi-capital
# 2020-02-06 11:06:32 lmsreporting
# 2020-03-18 12:15:17 sagemaker-us-east-1-500459076343
# 2022-03-03 11:16:30 syamil-bucket

# %% [markdown]
# # Data URIs from S3 Source

# %%
data_cutoff_date = (datetime.today() + timedelta(days=-1)).date()
hour_code = '08' # Get this when checking with aws s3.
data_cutoff_text = data_cutoff_date.strftime('%Y%m%d') + hour_code
dat = {
    'app': {'uri': f's3://adc-ds-lms/aspirasi/prod/lms/adc_lms/{data_cutoff_text}/application_tab/'},
    'contract': {'uri': f's3://adc-ds-lms/aspirasi/prod/lms/adc_lms/{data_cutoff_text}/contracts_tab/'},
    'product': {'uri': f's3://adc-ds-lms/aspirasi/prod/lms/adc_lms/{data_cutoff_text}/product_tab/'},
    'provision': {'uri': f's3://adc-ds-lms/aspirasi/prod/lms/adc_lms/{data_cutoff_text}/provisioning_metadata/'},
    'dot': {'uri': f's3://adc-ds-lms/aspirasi/prod/journey/prejourney_funnel/{data_cutoff_text}/digital_onboarding_tab.parquet/'},
    'repayment': {'uri': f's3://adc-my-reporting/lending/lmsv2_my_mwc_repayment/report_year={data_cutoff_date.year}/report_month={data_cutoff_date.month}/report_day={data_cutoff_date.day}/'},
    'meta': {'uri': f's3://adc-ds-lms/aspirasi/prod/journey/prejourney_funnel/{data_cutoff_text}/metadata_storage.parquet/'}
}

# %% [markdown]
# # Load Data from Parquet Referencing URIs

# %%
# Load Data
for _tab in tqdm(
    ('dot', 'contract', 'provision', 'meta', 'app'),
    desc='Reading Data',
    unit='table',
    colour='orange'
):
    dat.get(_tab, {})['df'] = read_parquet(dat.get(_tab, {}).get('uri', ''))
    if _tab=='meta':
        dat[_tab]['df']['ms_request_id'] = dat[_tab]['df']['ms_metadata']\
                                               .apply(lambda _: json_loads(_).get('requestID',
                                                                                  nan))
    elif _tab=='provision':
        dat[_tab]['df'].drop(
            index=dat[_tab]['df'].index[dat[_tab]['df']['pm_merchant_id'].eq(0)], 
            inplace=True
        )
# Out:
# Reading Data:   0%|          | 0/5 [00:00<?, ?table/s]

# %% [markdown]
# # Unify Dataset Tables

# %%
onboard_dat = dat.setdefault('onboarding', {})['df'] = dat['dot']['df'].merge(
    right=dat['meta']['df'],
    how='inner',
    left_on='dot_session_key',
    right_on='ms_tracker_id',
    copy=False
).merge(
    right=dat['provision']['df'],
    how='inner',
    left_on='ms_request_id',
    right_on='pm_originating_request_id',
    copy=False
).merge(
    right=dat['app']['df'],
    how='inner',
    left_on='pm_merchant_id',
    right_on='at_merchant_id',
    copy=False
).merge(
    right=dat['contract']['df'],
    how='inner',
    left_on='at_id',
    right_on='ct_originating_application_id',
    copy=False
)
onboard_dat.replace(to_replace={None: nan}, inplace=True)
onboard_dat = onboard_dat.convert_dtypes()

# Drop Redundant Columns
onboard_dat.drop(columns=['dot_session_key', 'ms_request_id', 'pm_merchant_id', 'at_id'],
                 inplace=True)

# Identify Records by ID
onboard_dat.set_index(keys=['dot_id',
                            'ms_tracker_id',
                            'pm_originating_request_id',
                            'at_merchant_id',
                            'ct_originating_application_id'],
                      drop=True,
                      inplace=True)

# %% [markdown]
# ## Preview

# %%
from math import ceil
def get_sample_size(
    population_size: int,
    confidence_level: float=0.95,
    margin_of_error: float=0.05
) -> int:
    num_num = 0.25 * confidence_level**2
    num_den = margin_of_error**2
    num = num_num * num_den**(-1)
    return ceil(num * (1 + num * population_size**(-1))**(-1))

# %%
onboard_dat.sample(n=get_sample_size(onboard_dat.shape[0], 0.9, 0.1), 
                   random_state=42).transpose(copy=False)
# Out:
# dot_id                                                           250169  \
# ms_tracker_id                      79a840e8-f780-11eb-ae4a-0a5843143288
# pm_originating_request_id     ELIG_f4408dd3-7e68-43ac-910e-b6ffd4bc3843
# at_merchant_id                                                    65655
# ct_originating_application_id                                    109678
# dot_record_create_date                              2021-08-07 13:07:54
# dot_record_update_date                              2021-08-07 13:11:06
# dot_full_name                                          Mindy Ng yim kun
# dot_identity_card                                        831228-07-5226
# dot_owner_phone_number                                      60165570097
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                    2021-08-09 08:00:55
# ct_approved_by                                            faizalridzuan
# ct_fund_source                                                        0
#
# dot_id                                                           143883  \
# ms_tracker_id                      e578eeff-5159-11eb-a321-0a5843143288
# pm_originating_request_id     ELIG_475c6c60-cbda-4469-8a19-f3369a06a102
# at_merchant_id                                                    55477
# ct_originating_application_id                                     79732
# dot_record_create_date                              2021-01-08 02:33:31
# dot_record_update_date                              2021-01-08 02:45:33
# dot_full_name                                   FARAFADYLLA BT ZULKIFLY
# dot_identity_card                                        820512-11-5156
# dot_owner_phone_number                                      60137526609
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                            23713  \
# ms_tracker_id                      11d23e13-b47e-11ea-a321-0a5843143288
# pm_originating_request_id     ELIG_d4fba4d6-fbf2-41eb-a6e7-95f7883daf3c
# at_merchant_id                                                    36979
# ct_originating_application_id                                     22135
# dot_record_create_date                              2020-06-22 11:47:15
# dot_record_update_date                              2020-06-22 11:52:21
# dot_full_name                                                Khoo edwin
# dot_identity_card                                        760729-07-5667
# dot_owner_phone_number                                      60133625763
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                            31674  \
# ms_tracker_id                      eca1c630-ba00-11ea-a321-0a5843143288
# pm_originating_request_id     ELIG_1c9f0bbf-4dca-4d51-bd19-2e5281483f63
# at_merchant_id                                                    37681
# ct_originating_application_id                                     24898
# dot_record_create_date                              2020-06-29 12:06:17
# dot_record_update_date                              2020-06-29 12:13:27
# dot_full_name                        MUHAMMAD AIDIL AMIRUL BIN ROSNIZAM
# dot_identity_card                                        980802-56-5051
# dot_owner_phone_number                                     601163391001
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                            86617  \
# ms_tracker_id                      a099ff38-0859-11eb-a321-0a5843143288
# pm_originating_request_id     ELIG_6a97dda6-e8d5-48f4-80bc-bb1b11b0a598
# at_merchant_id                                                    47350
# ct_originating_application_id                                     48145
# dot_record_create_date                              2020-10-07 04:58:31
# dot_record_update_date                              2020-10-07 05:10:12
# dot_full_name                                          Abdullah Suhaimi
# dot_identity_card                                        821229-03-5139
# dot_owner_phone_number                                      60199753082
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                            28319  \
# ms_tracker_id                      e7c753e1-b758-11ea-a321-0a5843143288
# pm_originating_request_id     ELIG_1a178bc6-10eb-435d-a968-be69b2c36443
# at_merchant_id                                                    37390
# ct_originating_application_id                                     43250
# dot_record_create_date                              2020-06-26 02:58:37
# dot_record_update_date                              2020-06-26 03:06:16
# dot_full_name                                  Intan nazira binti rosli
# dot_identity_card                                        920422-08-6580
# dot_owner_phone_number                                      60189069201
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                            10505  \
# ms_tracker_id                      8dbc3afc-9985-11ea-a321-0a5843143288
# pm_originating_request_id     ELIG_7bd759a5-6971-47b6-bce4-24a67b19f5fa
# at_merchant_id                                                    26187
# ct_originating_application_id                                     14647
# dot_record_create_date                              2020-05-19 04:02:43
# dot_record_update_date                              2020-05-19 04:08:26
# dot_full_name                                 gul zaman bin gull rahman
# dot_identity_card                                        800430-11-5437
# dot_owner_phone_number                                      60163342786
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                            65848  \
# ms_tracker_id                      d478e59f-f0d0-11ea-a321-0a5843143288
# pm_originating_request_id     ELIG_ce780b03-91c2-44fa-ad00-2f1f66fc009a
# at_merchant_id                                                    45023
# ct_originating_application_id                                     40975
# dot_record_create_date                              2020-09-07 06:10:44
# dot_record_update_date                              2020-09-07 06:14:08
# dot_full_name                                      Kaiyisah binti hamil
# dot_identity_card                                        891030-08-5220
# dot_owner_phone_number                                      60189501090
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                           183481  \
# ms_tracker_id                      60d3311c-a310-11eb-ae4a-0a5843143288
# pm_originating_request_id     ELIG_7f878b05-5699-4453-ac71-85a70048f1d4
# at_merchant_id                                                    62815
# ct_originating_application_id                                     93015
# dot_record_create_date                              2021-04-22 02:13:50
# dot_record_update_date                              2021-04-22 02:23:40
# dot_full_name                                     AZURA BINTI ALI SUPIA
# dot_identity_card                                        810914-08-6280
# dot_owner_phone_number                                      60173387516
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                           253898  ...  \
# ms_tracker_id                      cd715e84-fe74-11eb-ae4a-0a5843143288  ...
# pm_originating_request_id     ELIG_8b4e872b-bffa-4cc6-8655-2e55df639ded  ...
# at_merchant_id                                                    65885  ...
# ct_originating_application_id                                    110627  ...
# dot_record_create_date                              2021-08-16 09:31:59  ...
# dot_record_update_date                              2021-08-16 10:58:47  ...
# dot_full_name                                             Raymond David  ...
# dot_identity_card                                        740813-14-5105  ...
# dot_owner_phone_number                                      60105215216  ...
# ...                                                                 ...  ...
# ct_partner_id                                                      <NA>  ...
# ct_rejection_reason                                                <NA>  ...
# ct_approved_date                                    2021-08-17 09:24:11  ...
# ct_approved_by                                            azlinsyafinas  ...
# ct_fund_source                                                        0  ...
#
# dot_id                                                           149025  \
# ms_tracker_id                      65db4a26-675d-11eb-a321-0a5843143288
# pm_originating_request_id     ELIG_c1979263-f76a-44ca-b81b-75e622ebb02b
# at_merchant_id                                                    57149
# ct_originating_application_id                                     80303
# dot_record_create_date                              2021-02-05 02:54:27
# dot_record_update_date                              2021-02-05 02:58:40
# dot_full_name                                            Chan Mann Shih
# dot_identity_card                                        940511-07-5726
# dot_owner_phone_number                                      60135181876
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                            14524  \
# ms_tracker_id                      d5856e06-a48d-11ea-a321-0a5843143288
# pm_originating_request_id     ELIG_32d5f99b-890c-4e43-af60-191c949575cc
# at_merchant_id                                                    36323
# ct_originating_application_id                                     18336
# dot_record_create_date                              2020-06-02 04:59:45
# dot_record_update_date                              2020-06-02 05:03:58
# dot_full_name                                    STEPFEN YEOH LIAN KIAT
# dot_identity_card                                        881209-06-5191
# dot_owner_phone_number                                      60169608083
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                           105139  \
# ms_tracker_id                      7d47f6ab-1278-11eb-a321-0a5843143288
# pm_originating_request_id     ELIG_37cb0f61-9eb3-4e65-864e-be320eb7ee6e
# at_merchant_id                                                    49240
# ct_originating_application_id                                     56965
# dot_record_create_date                              2020-10-20 02:04:15
# dot_record_update_date                              2020-10-20 02:10:40
# dot_full_name                                   Fadhilah binti md sidek
# dot_identity_card                                        851029-10-5670
# dot_owner_phone_number                                      60132332238
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                            82569  \
# ms_tracker_id                      271dda07-06b4-11eb-a321-0a5843143288
# pm_originating_request_id     ELIG_9df63485-2fae-4925-9975-5371b06e576d
# at_merchant_id                                                    46213
# ct_originating_application_id                                     46750
# dot_record_create_date                              2020-10-05 02:40:52
# dot_record_update_date                              2020-10-05 02:48:56
# dot_full_name                                   MOHD SUHAIMI BIN KHAULI
# dot_identity_card                                        840312-11-5483
# dot_owner_phone_number                                      60199852755
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                           266905  \
# ms_tracker_id                      b154f549-1a74-11ec-ae4a-0a5843143288
# pm_originating_request_id     ELIG_d133e87a-ef40-492b-9ce3-b9fab79b33d3
# at_merchant_id                                                    66940
# ct_originating_application_id                                    114249
# dot_record_create_date                              2021-09-21 00:41:44
# dot_record_update_date                              2021-09-21 00:46:09
# dot_full_name                               HARITH FADZILAH BIN MAHAZIR
# dot_identity_card                                        780822-08-6561
# dot_owner_phone_number                                      60173769686
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                    2021-09-22 10:43:13
# ct_approved_by                                            azlinsyafinas
# ct_fund_source                                                        0
#
# dot_id                                                             2392  \
# ms_tracker_id                      d64dae66-8bc9-11ea-a321-0a5843143288
# pm_originating_request_id     ELIG_6dd9d295-2613-4e29-adf4-d8efabbadb5c
# at_merchant_id                                                    15638
# ct_originating_application_id                                     17308
# dot_record_create_date                              2020-05-01 16:36:10
# dot_record_update_date                              2020-05-01 16:46:09
# dot_full_name                        zulaikah intan noratika bt ibrahim
# dot_identity_card                                        911225-08-6624
# dot_owner_phone_number                                      60127163876
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                            23065  \
# ms_tracker_id                      9175ed1f-b426-11ea-a321-0a5843143288
# pm_originating_request_id     ELIG_5a4f0a52-8068-4901-92b2-d95fe6045787
# at_merchant_id                                                    36917
# ct_originating_application_id                                     21708
# dot_record_create_date                              2020-06-22 01:21:14
# dot_record_update_date                              2020-06-22 01:29:55
# dot_full_name                                        Siti nor ain rahim
# dot_identity_card                                        890107-11-5682
# dot_owner_phone_number                                      60129091873
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                            56231  \
# ms_tracker_id                      345a9106-e1c9-11ea-a321-0a5843143288
# pm_originating_request_id     ELIG_6de20911-5432-432d-816f-6fd9f29ed440
# at_merchant_id                                                    44334
# ct_originating_application_id                                     36318
# dot_record_create_date                              2020-08-19 03:08:31
# dot_record_update_date                              2020-08-19 03:12:07
# dot_full_name                                    Nur Azila Binti Hussin
# dot_identity_card                                        930721-01-6506
# dot_owner_phone_number                                      60127318457
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                           136114  \
# ms_tracker_id                      6aec7881-3ade-11eb-a321-0a5843143288
# pm_originating_request_id     ELIG_49289103-5d08-41b8-8558-93a1b16d1b54
# at_merchant_id                                                    54947
# ct_originating_application_id                                     69849
# dot_record_create_date                              2020-12-10 11:54:19
# dot_record_update_date                              2020-12-10 12:01:31
# dot_full_name                               EIDDIL EIRMIZZAD BIN AFFZAL
# dot_identity_card                                        950306-10-6107
# dot_owner_phone_number                                      60182050255
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# dot_id                                                           174618
# ms_tracker_id                      62026c30-9a61-11eb-ae4a-0a5843143288
# pm_originating_request_id     ELIG_65f02f7a-5245-4c92-9369-fc2c7a518930
# at_merchant_id                                                    62497
# ct_originating_application_id                                     90216
# dot_record_create_date                              2021-04-11 01:01:01
# dot_record_update_date                              2021-04-11 01:06:16
# dot_full_name                                              CHAI MEI QI
# dot_identity_card                                        991118-01-5938
# dot_owner_phone_number                                      60123259603
# ...                                                                 ...
# ct_partner_id                                                      <NA>
# ct_rejection_reason                                                <NA>
# ct_approved_date                                                    NaT
# ct_approved_by                                                     <NA>
# ct_fund_source                                                        0
#
# [121 rows x 21 columns]
